# %%
from bs4 import BeautifulSoup
import time
import pandas as pd
import requests
import csv


url = 'https://www.tgju.org/profile/geram18/history'
responce = requests.get(url)
soup = BeautifulSoup(responce.text, 'html.parser')

cell = soup.select_one('#table-list > tr:nth-child(1) ')
tds = cell.find_all('td')

date_str = tds[6].text.strip()

#filename_date = date_str.replace('/', '-')
filename = f"Gold18 Price {filename_date}.csv"



row = [
    date_str,
    tds[3].text.strip(),
    # tds[0].text.strip(),
    # tds[1].text.strip(),
    # tds[2].text.strip(),
    # tds[5].text.strip(),

]

# Columns names
# header = ['Today Date','Ending Price', 'Beginning Price', 'Min Price', 'Max Price', 'Percentage']
header = ['Today Date']
# Write in csv file  
with open(filename, 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(header) 
    writer.writerow(row)   

print(f"اطلاعات در فایل CSV با نام {filename} ذخیره شد.")
# Out:
# اطلاعات در فایل CSV با نام Gold18 Price 2025-06-29.csv ذخیره شد.

# %%
import requests

url = "https://api.tgju.org/v1/market/indicator/summary-table-data/geram18"
params = {
    "lang": "fa",
    "order_dir": "asc",
    "draw": 14,
    "columns[0][data]": 0,
    "columns[0][name]": "",
    "columns[0][searchable]": "true",
    "columns[0][orderable]": "true",
    "columns[0][search][value]": "",
    "columns[0][search][regex]": "false",
    "columns[1][data]": 1,
    "columns[1][name]": "",
    "columns[1][searchable]": "true",
    "columns[1][orderable]": "true",
    "columns[1][search][value]": "",
    "columns[1][search][regex]": "false",
    "columns[2][data]": 2,
    "columns[2][name]": "",
    "columns[2][searchable]": "true",
    "columns[2][orderable]": "true",
    "columns[2][search][value]": "",
    "columns[2][search][regex]": "false",
    "columns[3][data]": 3,
    "columns[3][name]": "",
    "columns[3][searchable]": "true",
    "columns[3][orderable]": "true",
    "columns[3][search][value]": "",
    "columns[3][search][regex]": "false",
    "columns[4][data]": 4,
    "columns[4][name]": "",
    "columns[4][searchable]": "true",
    "columns[4][orderable]": "true",
    "columns[4][search][value]": "",
    "columns[4][search][regex]": "false",
    "columns[5][data]": 5,
    "columns[5][name]": "",
    "columns[5][searchable]": "true",
    "columns[5][orderable]": "true",
    "columns[5][search][value]": "",
    "columns[5][search][regex]": "false",
    "columns[6][data]": 6,
    "columns[6][name]": "",
    "columns[6][searchable]": "true",
    "columns[6][orderable]": "true",
    "columns[6][search][value]": "",
    "columns[6][search][regex]": "false",
    "columns[7][data]": 7,
    "columns[7][name]": "",
    "columns[7][searchable]": "true",
    "columns[7][orderable]": "true",
    "columns[7][search][value]": "",
    "columns[7][search][regex]": "false",
    "start": 60,
    "length": 30,
    "search": "",
    "order_col": "",
    "order_dir": "",
    "from": "1403/10/01",
    "to": "1404/04/11",
    "convert_to_ad": 1,
    "_": 1751372227798
}

response = requests.get(url, params=params)
data = response.json()
print(data)
# Out:
# {'draw': '14', 'recordsTotal': 141, 'recordsFiltered': 141, 'data': [['77,218,000', '77,218,000', '80,166,000', '79,863,000', '<span class="high" dir="ltr">2758000</span>', '<span class="high" dir="ltr">3.58%</span>', '2025/04/06', '1404/01/17'], ['82,461,000', '77,026,000', '82,461,000', '77,105,000', '<span class="low" dir="ltr">5277000</span>', '<span class="low" dir="ltr">6.84%</span>', '2025/04/05', '1404/01/16'], ['81,853,000', '81,853,000', '83,006,000', '82,382,000', '<span class="high" dir="ltr">565000</span>', '<span class="high" dir="ltr">0.69%</span>', '2025/04/03', '1404/01/14'], ['82,821,000', '81,066,000', '82,821,000', '81,817,000', '<span class="low" dir="ltr">997000</span>', '<span class="low" dir="ltr">1.22%</span>', '2025/03/30', '1404/01/10'], ['81,147,000', '81,147,000', '83,608,000', '82,814,000', '<span class="high" dir="ltr">1672000</span>', '<span class="high" dir="ltr">2.06%</span>', '2025/03/29', '1404/01/09'], ['79,951,000', '79,951,000', '81,507,000', '8
# ...

# %%
import requests
import json
import re
import pandas as pd

url = "https://api.tgju.org/v1/market/indicator/summary-table-data/geram18"

params = {
    "lang": "fa",
    "order_dir": "asc",
    "draw": 5,
    "columns[0][data]": 0,
    "columns[0][name]": "",
    "columns[0][searchable]": "true",
    "columns[0][orderable]": "true",
    "columns[0][search][value]": "",
    "columns[0][search][regex]": "false",
    "columns[1][data]": 1,
    "columns[1][name]": "",
    "columns[1][searchable]": "true",
    "columns[1][orderable]": "true",
    "columns[1][search][value]": "",
    "columns[1][search][regex]": "false",
    "columns[2][data]": 2,
    "columns[2][name]": "",
    "columns[2][searchable]": "true",
    "columns[2][orderable]": "true",
    "columns[2][search][value]": "",
    "columns[2][search][regex]": "false",
    "columns[3][data]": 3,
    "columns[3][name]": "",
    "columns[3][searchable]": "true",
    "columns[3][orderable]": "true",
    "columns[3][search][value]": "",
    "columns[3][search][regex]": "false",
    "columns[4][data]": 4,
    "columns[4][name]": "",
    "columns[4][searchable]": "true",
    "columns[4][orderable]": "true",
    "columns[4][search][value]": "",
    "columns[4][search][regex]": "false",
    "columns[5][data]": 5,
    "columns[5][name]": "",
    "columns[5][searchable]": "true",
    "columns[5][orderable]": "true",
    "columns[5][search][value]": "",
    "columns[5][search][regex]": "false",
    "columns[6][data]": 6,
    "columns[6][name]": "",
    "columns[6][searchable]": "true",
    "columns[6][orderable]": "true",
    "columns[6][search][value]": "",
    "columns[6][search][regex]": "false",
    "columns[7][data]": 7,
    "columns[7][name]": "",
    "columns[7][searchable]": "true",
    "columns[7][orderable]": "true",
    "columns[7][search][value]": "",
    "columns[7][search][regex]": "false",
    "start": 0,
    "length": 30,
    "search": "",
    "order_col": "",
    "order_dir": "",
    "from": "1403/10/01",
    "to": "1404/04/11",
    "convert_to_ad": 1,
    "_": 1751375776284
}
raw_data = []
def clean_html(text):
    return re.sub('<.*?>', '', text).replace(',', '')

def clean_percent(text):
    return re.sub('<.*?>', '', text).replace('%','').strip()

try:
    response = requests.get(url, params=params)
    response.raise_for_status()
    result = response.json()

    data = result.get('data', [])

    # پاکسازی و ساخت دیتافریم
    cleaned_rows = []
    for row in data:
        cleaned_row = [
            clean_html(row[0]),  # Ending Price
            clean_html(row[1]),  # Beginning Price
            clean_html(row[3]),  # Min Price
            clean_html(row[2]),  # Max Price
            clean_html(row[4]),  # Change
            clean_percent(row[5]),  # Percentage
            row[6],  # Today Date (AD)
            row[7],  # Persian Date
        ]
        cleaned_rows.append(cleaned_row)

    df = pd.DataFrame(cleaned_rows, columns=[
        'Ending Price', 'Beginning Price', 'Min Price', 'Max Price', 'Change', 'Percentage', 'Today Date (AD)', 'Persian Date'
    ])

    # مرتب سازی نزولی بر اساس تاریخ میلادی
    df = df.sort_values(by='Today Date (AD)', ascending=False).reset_index(drop=True)

    # ذخیره به CSV
    df.to_csv('Gold18_with_PersianDate.csv', index=False, encoding='utf-8-sig')

    print("فایل Gold18_with_PersianDate.csv با موفقیت ذخیره شد.")

except Exception as e:
    print("خطا در دریافت یا پردازش داده‌ها:", e)
# Out:
# فایل Gold18_with_PersianDate.csv با موفقیت ذخیره شد.
# نمونه داده‌ها:
#   Ending Price Beginning Price Min Price Max Price   Change Percentage  \
# 0     70871000        70857000  73563000  74597000  2888000       4.09
# 1     67422000        67413000  70675000  71418000  3234000        4.8
# 2     67173000        66912000  67441000  67858000   252000       0.38
# 3     66829000        66813000  67189000  67678000   346000       0.52
# 4     72956000        66471000  66843000  72965000   898000       1.34
#
#   Today Date (AD) Persian Date
# 0      2025/06/30   1404/04/09
# 1      2025/06/29   1404/04/08
# 2      2025/06/28   1404/04/07
# 3      2025/06/26   1404/04/05
# 4      2025/06/25   1404/04/04

# %%
import requests
import json

url = "https://api.tgju.org/v1/market/indicator/summary-table-data/geram18"

params = {
    "lang": "fa",
    "order_dir": "asc",
    "draw": 5,
    "columns[0][data]": 0,
    "columns[0][name]": "",
    "columns[0][searchable]": "true",
    "columns[0][orderable]": "true",
    "columns[0][search][value]": "",
    "columns[0][search][regex]": "false",
    "columns[1][data]": 1,
    "columns[1][name]": "",
    "columns[1][searchable]": "true",
    "columns[1][orderable]": "true",
    "columns[1][search][value]": "",
    "columns[1][search][regex]": "false",
    "columns[2][data]": 2,
    "columns[2][name]": "",
    "columns[2][searchable]": "true",
    "columns[2][orderable]": "true",
    "columns[2][search][value]": "",
    "columns[2][search][regex]": "false",
    "columns[3][data]": 3,
    "columns[3][name]": "",
    "columns[3][searchable]": "true",
    "columns[3][orderable]": "true",
    "columns[3][search][value]": "",
    "columns[3][search][regex]": "false",
    "columns[4][data]": 4,
    "columns[4][name]": "",
    "columns[4][searchable]": "true",
    "columns[4][orderable]": "true",
    "columns[4][search][value]": "",
    "columns[4][search][regex]": "false",
    "columns[5][data]": 5,
    "columns[5][name]": "",
    "columns[5][searchable]": "true",
    "columns[5][orderable]": "true",
    "columns[5][search][value]": "",
    "columns[5][search][regex]": "false",
    "columns[6][data]": 6,
    "columns[6][name]": "",
    "columns[6][searchable]": "true",
    "columns[6][orderable]": "true",
    "columns[6][search][value]": "",
    "columns[6][search][regex]": "false",
    "columns[7][data]": 7,
    "columns[7][name]": "",
    "columns[7][searchable]": "true",
    "columns[7][orderable]": "true",
    "columns[7][search][value]": "",
    "columns[7][search][regex]": "false",
    "start": 0,
    "length": 141,
    "search": "",
    "order_col": "",
    "order_dir": "",
    "from": "1403/10/01",
    "to": "1404/04/11",
    "convert_to_ad": 1,
    "_": 1751375776284
}

try:
    response = requests.get(url, params=params)
    response.raise_for_status()
    result = response.json()

    # داده‌ها به صورت خام (شامل HTML) در row_data
    row_data = result.get("data", [])

    # نمایش نمونه
    for row in row_data[:3]:
        print(row)

except Exception as e:
    print("خطا:", e)
# Out:
# ['74,025,000', '72,951,000', '75,223,000', '74,997,000', '<span class="high" dir="ltr">924000</span>', '<span class="high" dir="ltr">1.25%</span>', '2025/07/02', '1404/04/11']
# ['73,418,000', '73,418,000', '76,059,000', '74,073,000', '<span class="high" dir="ltr">510000</span>', '<span class="high" dir="ltr">0.69%</span>', '2025/07/01', '1404/04/10']
# ['70,871,000', '70,857,000', '74,597,000', '73,563,000', '<span class="high" dir="ltr">2888000</span>', '<span class="high" dir="ltr">4.09%</span>', '2025/06/30', '1404/04/09']

# %%
import requests
import json

url = "https://api.tgju.org/v1/market/indicator/summary-table-data/geram18"

params = {
    "lang": "fa",
    "order_dir": "asc",
    "draw": 5,
    "columns[0][data]": 0,
    "columns[0][name]": "",
    "columns[0][searchable]": "true",
    "columns[0][orderable]": "true",
    "columns[0][search][value]": "",
    "columns[0][search][regex]": "false",
    "columns[1][data]": 1,
    "columns[1][name]": "",
    "columns[1][searchable]": "true",
    "columns[1][orderable]": "true",
    "columns[1][search][value]": "",
    "columns[1][search][regex]": "false",
    "columns[2][data]": 2,
    "columns[2][name]": "",
    "columns[2][searchable]": "true",
    "columns[2][orderable]": "true",
    "columns[2][search][value]": "",
    "columns[2][search][regex]": "false",
    "columns[3][data]": 3,
    "columns[3][name]": "",
    "columns[3][searchable]": "true",
    "columns[3][orderable]": "true",
    "columns[3][search][value]": "",
    "columns[3][search][regex]": "false",
    "columns[4][data]": 4,
    "columns[4][name]": "",
    "columns[4][searchable]": "true",
    "columns[4][orderable]": "true",
    "columns[4][search][value]": "",
    "columns[4][search][regex]": "false",
    "columns[5][data]": 5,
    "columns[5][name]": "",
    "columns[5][searchable]": "true",
    "columns[5][orderable]": "true",
    "columns[5][search][value]": "",
    "columns[5][search][regex]": "false",
    "columns[6][data]": 6,
    "columns[6][name]": "",
    "columns[6][searchable]": "true",
    "columns[6][orderable]": "true",
    "columns[6][search][value]": "",
    "columns[6][search][regex]": "false",
    "columns[7][data]": 7,
    "columns[7][name]": "",
    "columns[7][searchable]": "true",
    "columns[7][orderable]": "true",
    "columns[7][search][value]": "",
    "columns[7][search][regex]": "false",
    "start": 0,
    "length": 141,
    "search": "",
    "order_col": "",
    "order_dir": "",
    "from": "1403/10/1",
    "to": "1404/04/12",
    "convert_to_ad": 1,
    "_": 1751375776284
}

try:
    response = requests.get(url, params=params)
    response.raise_for_status()
    result = response.json()

    # داده‌ها در کلید "data" به صورت لیست ردیف‌ها هستند
    row_data = result.get("data", [])
    extracted = []
    for row in row_data:
        date = row[-1]  
        price = row[3]  
        extracted.append({"date": date, "price": price})

    print(json.dumps(extracted[:10], ensure_ascii=False, indent=2))

except Exception as e:
    print("خطا در دریافت یا پردازش داده‌ها:", e)
# Out:
# [
#   {
#     "date": "1404/04/12",
#     "price": "74,371,000"
#   },
#   {
#     "date": "1404/04/11",
#     "price": "74,997,000"
#   },
#   {
#     "date": "1404/04/10",
#     "price": "74,073,000"
#   },
#   {
#     "date": "1404/04/09",
#     "price": "73,563,000"
#   },
#   {
#     "date": "1404/04/08",
#     "price": "70,675,000"
#   },
#   {
#     "date": "1404/04/07",
#     "price": "67,441,000"
#   },
#   {
#     "date": "1404/04/05",
#     "price": "67,189,000"
#   },
#   {
#     "date": "1404/04/04",
#     "price": "66,843,000"
#   },
#   {
#     "date": "1404/03/22",
#     "price": "67,741,000"
#   },
#   {
#     "date": "1404/03/21",
#     "price": "65,887,000"
#   }
# ]

# %%
len(extracted)
# Out:
# 141

# %%
extracted[-1]
# Out:
# {'date': '1403/10/04', 'price': '50,493,000'}

# %%
import requests
import re
import pandas as pd

def clean_html(text):
    import re
    return re.sub('<.*?>', '', text).replace(',', '')

def clean_percent(text):
    import re
    return re.sub('<.*?>', '', text).replace('%','').strip()

def fetch_and_save_api_data():
    url = "https://api.tgju.org/v1/market/indicator/summary-table-data/geram18"
    params = {
        "lang": "fa",
        "order_dir": "asc",
        "draw": 5,
        "columns[0][data]": 0,
        "columns[0][name]": "",
        "columns[0][searchable]": "true",
        "columns[0][orderable]": "true",
        "columns[0][search][value]": "",
        "columns[0][search][regex]": "false",
        "columns[1][data]": 1,
        "columns[1][name]": "",
        "columns[1][searchable]": "true",
        "columns[1][orderable]": "true",
        "columns[1][search][value]": "",
        "columns[1][search][regex]": "false",
        "columns[2][data]": 2,
        "columns[2][name]": "",
        "columns[2][searchable]": "true",
        "columns[2][orderable]": "true",
        "columns[2][search][value]": "",
        "columns[2][search][regex]": "false",
        "columns[3][data]": 3,
        "columns[3][name]": "",
        "columns[3][searchable]": "true",
        "columns[3][orderable]": "true",
        "columns[3][search][value]": "",
        "columns[3][search][regex]": "false",
        "columns[4][data]": 4,
        "columns[4][name]": "",
        "columns[4][searchable]": "true",
        "columns[4][orderable]": "true",
        "columns[4][search][value]": "",
        "columns[4][search][regex]": "false",
        "columns[5][data]": 5,
        "columns[5][name]": "",
        "columns[5][searchable]": "true",
        "columns[5][orderable]": "true",
        "columns[5][search][value]": "",
        "columns[5][search][regex]": "false",
        "columns[6][data]": 6,
        "columns[6][name]": "",
        "columns[6][searchable]": "true",
        "columns[6][orderable]": "true",
        "columns[6][search][value]": "",
        "columns[6][search][regex]": "false",
        "columns[7][data]": 7,
        "columns[7][name]": "",
        "columns[7][searchable]": "true",
        "columns[7][orderable]": "true",
        "columns[7][search][value]": "",
        "columns[7][search][regex]": "false",
        "start": 0,
        "length": 30,
        "search": "",
        "order_col": "",
        "order_dir": "",
        "from": "1403/10/01",
        "to": "1404/04/11",
        "convert_to_ad": 1,
        "_": 1751375776284
    }

    try:
        response = requests.get(url, params=params)
        response.raise_for_status()
        result = response.json()
        data = result.get('data', [])

        cleaned_rows = []
        for row in data:
            cleaned_row = [
                clean_html(row[0]),  # Ending Price
                clean_html(row[1]),  # Beginning Price
                clean_html(row[3]),  # Min Price
                clean_html(row[2]),  # Max Price
                clean_html(row[4]),  # Change
                clean_percent(row[5]),  # Percentage
                row[6],  # Today Date (AD)
                row[7],  # Persian Date
            ]
            cleaned_rows.append(cleaned_row)

        df = pd.DataFrame(cleaned_rows, columns=[
            'Ending Price', 'Beginning Price', 'Min Price', 'Max Price', 'Change', 'Percentage', 'Today Date (AD)', 'Persian Date'
        ])
        df = df.sort_values(by='Today Date (AD)', ascending=False).reset_index(drop=True)
        csv_filename = 'Gold18_with_PersianDate.csv'
        df.to_csv(csv_filename, index=False, encoding='utf-8-sig')
        print("فایل Gold18_with_PersianDate.csv با موفقیت ذخیره شد.")
    except Exception as e:
        print("خطا در دریافت یا پردازش داده‌ها:", e)

if __name__ == "__main__":
    fetch_and_save_api_data()
# Out:
# فایل Gold18_with_PersianDate.csv با موفقیت ذخیره شد.

# %%
import requests
import csv

url = "https://api.tgju.org/v1/market/indicator/summary-table-data/geram18"

params = {
    "lang": "fa",
    "order_dir": "asc",
    "draw": 5,
    "columns[0][data]": 0,
    "columns[0][name]": "",
    "columns[0][searchable]": "true",
    "columns[0][orderable]": "true",
    "columns[0][search][value]": "",
    "columns[0][search][regex]": "false",
    "columns[1][data]": 1,
    "columns[1][name]": "",
    "columns[1][searchable]": "true",
    "columns[1][orderable]": "true",
    "columns[1][search][value]": "",
    "columns[1][search][regex]": "false",
    "columns[2][data]": 2,
    "columns[2][name]": "",
    "columns[2][searchable]": "true",
    "columns[2][orderable]": "true",
    "columns[2][search][value]": "",
    "columns[2][search][regex]": "false",
    "columns[3][data]": 3,
    "columns[3][name]": "",
    "columns[3][searchable]": "true",
    "columns[3][orderable]": "true",
    "columns[3][search][value]": "",
    "columns[3][search][regex]": "false",
    "columns[4][data]": 4,
    "columns[4][name]": "",
    "columns[4][searchable]": "true",
    "columns[4][orderable]": "true",
    "columns[4][search][value]": "",
    "columns[4][search][regex]": "false",
    "columns[5][data]": 5,
    "columns[5][name]": "",
    "columns[5][searchable]": "true",
    "columns[5][orderable]": "true",
    "columns[5][search][value]": "",
    "columns[5][search][regex]": "false",
    "columns[6][data]": 6,
    "columns[6][name]": "",
    "columns[6][searchable]": "true",
    "columns[6][orderable]": "true",
    "columns[6][search][value]": "",
    "columns[6][search][regex]": "false",
    "columns[7][data]": 7,
    "columns[7][name]": "",
    "columns[7][searchable]": "true",
    "columns[7][orderable]": "true",
    "columns[7][search][value]": "",
    "columns[7][search][regex]": "false",
    "start": 0,
    "length": 144,
    "search": "",
    "order_col": "",
    "order_dir": "",
    "from": "1403/10/1",
    "to": "1404/04/12",
    "convert_to_ad": 1,
    "_": 1751375776284
}

try:
    response = requests.get(url, params=params)
    response.raise_for_status()
    result = response.json()

    row_data = result.get("data", [])
    extracted = []
    for row in row_data:
        date = row[-1]
        price = row[3]
        extracted.append({"date": date, "price": price})

    # ذخیره در فایل CSV
    with open('output.csv', 'w', newline='', encoding='utf-8-sig') as csvfile:
        fieldnames = ['date', 'price']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

        writer.writeheader()
        for item in extracted[:144]:  
            writer.writerow(item)

    print("داده‌ها با موفقیت در فایل output.csv ذخیره شدند.")

except Exception as e:
    print("خطا در دریافت یا پردازش داده‌ها:", e)
# Out:
# داده‌ها با موفقیت در فایل output.csv ذخیره شدند.

# %%
pip install persiantools
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
